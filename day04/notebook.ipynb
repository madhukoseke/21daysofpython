# %% [markdown]
# # Day 4: Tuples & Sets
#
# Welcome to Day 4! Today we'll explore two more important data structures: tuples and sets.
#
# ---
#
# ## 📚 Topic Introduction
#
# ### Tuples
# **Tuples** are ordered, immutable collections. Once created, they cannot be modified.
#
# Key characteristics:
# - **Ordered**: Maintain their order
# - **Immutable**: Cannot be changed after creation
# - **Allow duplicates**: Can contain duplicate values
# - **Faster than lists**: More efficient for read-only data
#
# ### Sets
# **Sets** are unordered collections of unique elements.
#
# Key characteristics:
# - **Unordered**: No specific order
# - **Unique elements**: Automatically removes duplicates
# - **Mutable**: Can add/remove elements
# - **Fast lookups**: Very efficient for membership testing
#
# ---
#
# ## 🔍 Syntax & Rules
#
# ### Tuples:
# ```python
# empty_tuple = ()
# single_item = (1,)  # Note the comma
# my_tuple = (1, 2, 3)
# ```
#
# ### Sets:
# ```python
# empty_set = set()  # NOT {}
# my_set = {1, 2, 3}
# ```
#
# ---

# %% [markdown]
# ## 💡 Examples - Tuples

# %%
# Example 1: Creating tuples
empty_tuple = ()
single_item = (42,)  # Comma is required
coordinates = (10, 20)
rgb_color = (255, 128, 0)
mixed_tuple = (1, "hello", 3.14, True)

print("Empty:", empty_tuple)
print("Single:", single_item)
print("Coordinates:", coordinates)
print("RGB:", rgb_color)
print("Mixed:", mixed_tuple)
# Out:
# Empty: ()
# Single: (42,)
# Coordinates: (10, 20)
# RGB: (255, 128, 0)
# Mixed: (1, 'hello', 3.14, True)

# %%
# Example 2: Accessing tuple elements
fruits = ("apple", "banana", "cherry", "date")

print(f"First: {fruits[0]}")
print(f"Last: {fruits[-1]}")
print(f"Slice: {fruits[1:3]}")
# Out:
# First: apple
# Last: date
# Slice: ('banana', 'cherry')

# %%
# Example 3: Tuple unpacking
point = (10, 20, 30)
x, y, z = point
print(f"x = {x}, y = {y}, z = {z}")

# Swapping values using tuples
a, b = 5, 10
print(f"Before swap: a = {a}, b = {b}")
a, b = b, a
print(f"After swap: a = {a}, b = {b}")
# Out:
# x = 10, y = 20, z = 30
# Before swap: a = 5, b = 10
# After swap: a = 10, b = 5

# %%
# Example 4: Tuple methods
numbers = (1, 2, 3, 2, 4, 2, 5)

print(f"Count of 2: {numbers.count(2)}")
print(f"Index of 4: {numbers.index(4)}")
print(f"Length: {len(numbers)}")
# Out:
# Count of 2: 3
# Index of 4: 4
# Length: 7

# %% [markdown]
# ## 💡 Examples - Sets

# %%
# Example 5: Creating sets
empty_set = set()
numbers = {1, 2, 3, 4, 5}
fruits = {"apple", "banana", "cherry"}

# Sets remove duplicates automatically
duplicates = {1, 2, 2, 3, 3, 3, 4}
print("With duplicates removed:", duplicates)

# Creating set from list
my_list = [1, 2, 2, 3, 4, 4, 5]
my_set = set(my_list)
print("From list:", my_set)
# Out:
# With duplicates removed: {1, 2, 3, 4}
# From list: {1, 2, 3, 4, 5}

# %%
# Example 6: Adding and removing elements
fruits = {"apple", "banana"}
print("Original:", fruits)

fruits.add("cherry")
print("After add:", fruits)

fruits.remove("banana")  # Raises error if not found
print("After remove:", fruits)

fruits.discard("grape")  # No error if not found
print("After discard (no error):", fruits)
# Out:
# Original: {'apple', 'banana'}
# After add: {'apple', 'cherry', 'banana'}
# After remove: {'apple', 'cherry'}
# After discard (no error): {'apple', 'cherry'}

# %%
# Example 7: Set operations
set_a = {1, 2, 3, 4, 5}
set_b = {4, 5, 6, 7, 8}

# Union: all elements from both sets
print("Union:", set_a | set_b)
print("Union (method):", set_a.union(set_b))

# Intersection: common elements
print("Intersection:", set_a & set_b)
print("Intersection (method):", set_a.intersection(set_b))

# Difference: elements in A but not in B
print("Difference A-B:", set_a - set_b)
print("Difference (method):", set_a.difference(set_b))
# Out:
# Union: {1, 2, 3, 4, 5, 6, 7, 8}
# Union (method): {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection: {4, 5}
# Intersection (method): {4, 5}
# Difference A-B: {1, 2, 3}
# Difference (method): {1, 2, 3}

# %%
# Example 8: Set membership testing
fruits = {"apple", "banana", "cherry"}

print("Is 'apple' in fruits?", "apple" in fruits)
print("Is 'grape' in fruits?", "grape" in fruits)
print("Is 'grape' not in fruits?", "grape" not in fruits)
# Out:
# Is 'apple' in fruits? True
# Is 'grape' in fruits? False
# Is 'grape' not in fruits? True

# %% [markdown]
# ---
#
# ## ✏️ Practice Exercises

# %%
# Exercise 1: Create a tuple with 3 of your favorite colors

# Your code here
favorite_colors = ("blue", "green", "red")
print("Favorite colors:", favorite_colors)
# Out:
# Favorite colors: ('blue', 'green', 'red')

# %%
# Exercise 2: Access the first and last element from the tuple (10, 20, 30, 40, 50)

# Your code here
numbers = (10, 20, 30, 40, 50)
first_element = numbers[0]
last_element = numbers[-1]
print("First element:", first_element)
print("Last element:", last_element)
# Out:
# First element: 10
# Last element: 50

# %%
# Exercise 3: Unpack the tuple ("Alice", 25, "Engineer") into three variables

# Your code here
person = ("Alice", 25, "Engineer")
name, age, profession = person
print(f"Name: {name}, Age: {age}, Profession: {profession}")
# Out:
# Name: Alice, Age: 25, Profession: Engineer

# %%
# Exercise 4: Count how many times 5 appears in (1, 2, 5, 3, 5, 4, 5)

# Your code here
count_of_five = (1, 2, 5, 3, 5, 4, 5).count(5)
print("Count of 5:", count_of_five)
# Out:
# Count of 5: 3

# %%
# Exercise 5: Find the index of "banana" in ("apple", "banana", "cherry")

# Your code here
fruits = ("apple", "banana", "cherry")
banana_index = fruits.index("banana")
print("Index of 'banana':", banana_index)
# Out:
# Index of 'banana': 1

# %%
# Exercise 6: Create a set with numbers 1 through 5

# Your code here
number_set = {1, 2, 3, 4, 5}
print("Number set:", number_set)
# Out:
# Number set: {1, 2, 3, 4, 5}

# %%
# Exercise 7: Remove duplicates from the list [1, 2, 2, 3, 4, 4, 5] using a set

# Your code here
my_list = [1, 2, 2, 3, 4, 4, 5]
my_set = set(my_list)
print("Set without duplicates:", my_set)
# Out:
# Set without duplicates: {1, 2, 3, 4, 5}

# %%
# Exercise 8: Add "mango" to the set {"apple", "banana", "cherry"}

# Your code here
fruit_set = {"apple", "banana", "cherry"}
fruit_set.add("mango")
print("Set after adding mango:", fruit_set)
# Out:
# Set after adding mango: {'apple', 'mango', 'cherry', 'banana'}

# %%
# Exercise 9: Remove "banana" from {"apple", "banana", "cherry"}

# Your code here
fruit_set.remove("banana")
print("Set after removing banana:", fruit_set)
# Out:
# Set after removing banana: {'apple', 'mango', 'cherry'}

# %%
# Exercise 10: Check if "apple" is in the set {"apple", "banana", "cherry"}

# Your code here
fruit_set = {"apple", "banana", "cherry"}
is_apple_in_set = "apple" in fruit_set
print("Is 'apple' in the set?", is_apple_in_set)
# Out:
# Is 'apple' in the set? True

# %%
# Exercise 11: Find the union of {1, 2, 3} and {3, 4, 5}

# Your code here
set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1.union(set2)
print("Union of set1 and set2:", union_set)
# Out:
# Union of set1 and set2: {1, 2, 3, 4, 5}

# %%
# Exercise 12: Find the intersection of {1, 2, 3, 4} and {3, 4, 5, 6}

# Your code here
set_a = {1, 2, 3, 4}
set_b = {3, 4, 5, 6}
intersection_set = set_a.intersection(set_b)
print("Intersection of set_a and set_b:", intersection_set)
# Out:
# Intersection of set_a and set_b: {3, 4}

# %%
# Exercise 13: Find the difference between {1, 2, 3, 4} and {3, 4, 5}

# Your code here
set_x = {1, 2, 3, 4}
set_y = {3, 4, 5}
difference_set = set_x.difference(set_y)
print("Difference between set_x and set_y:", difference_set)
# Out:
# Difference between set_x and set_y: {1, 2}

# %%
# Exercise 14: Get the length of the set {10, 20, 30, 40, 50}

# Your code here
length_of_set = len({10, 20, 30, 40, 50})
print("Length of the set:", length_of_set)
# Out:
# Length of the set: 5

# %%
# Exercise 15: Create a tuple of coordinates (x, y) and print x and y separately

# Your code here
coordinates = (15, 25)
x, y = coordinates
print(f"x: {x}, y: {y}")
# Out:
# x: 15, y: 25

# %% [markdown]
# ---
#
# ## 🎯 Challenge Problems

# %%
# Challenge 1: Find elements that are in set A or set B, but not in both
# (symmetric difference)
# set_a = {1, 2, 3, 4}
# set_b = {3, 4, 5, 6}
# Result should be {1, 2, 5, 6}

# Your code here
set_a = {1, 2, 3, 4}
set_b = {3, 4, 5, 6}
symmetric_difference = set_a.symmetric_difference(set_b)
print("Symmetric difference between set_a and set_b:", symmetric_difference)
# Out:
# Symmetric difference between set_a and set_b: {1, 2, 5, 6}

# %%
# Challenge 2: Check if set A is a subset of set B
# set_a = {1, 2}
# set_b = {1, 2, 3, 4}

# Your code here
set_a = {1, 2}
set_b = {1, 2, 3, 4}
is_subset = set_a.issubset(set_b)
print("Is set_a a subset of set_b?", is_subset)
# Out:
# Is set_a a subset of set_b? True

# %%
# Challenge 3: Given a list of tuples representing (name, score),
# find the person with the highest score
# students = [("Alice", 85), ("Bob", 92), ("Charlie", 78)]

# Your code here
students = [("Alice", 85), ("Bob", 92), ("Charlie", 78)]
top_student = max(students, key=lambda student: student[1])
print(f"Top student: {top_student[0]} with score {top_student[1]}")
# Out:
# Top student: Bob with score 92

# %%
# Challenge 4: Find common elements across three sets
# set1 = {1, 2, 3, 4, 5}
# set2 = {3, 4, 5, 6, 7}
# set3 = {5, 6, 7, 8, 9}

# Your code here
set1 = {1, 2, 3, 4, 5}
set2 = {3, 4, 5, 6, 7}
set3 = {5, 6, 7, 8, 9}
common_elements = set1.intersection(set2).intersection(set3)
print("Common elements across set1, set2, and set3:", common_elements)
# Out:
# Common elements across set1, set2, and set3: {5}

# %%
# Challenge 5: Convert a string to a set of unique characters
# and count how many unique characters there are
# text = "programming"

# Your code here
text = "programming"
unique_characters = set(text)
count_unique_characters = len(unique_characters)
print("Unique characters:", unique_characters)
print("Count of unique characters:", count_unique_characters)
# Out:
# Unique characters: {'g', 'n', 'i', 'o', 'p', 'm', 'a', 'r'}
# Count of unique characters: 8

# %% [markdown]
# ---
#
# ## ✅ Solutions

# %% [markdown]
# ### Practice Exercise Solutions

# %%
# Solution 1
colors = ("blue", "green", "red")
print(colors)

# %%
# Solution 2
numbers = (10, 20, 30, 40, 50)
print(f"First: {numbers[0]}")
print(f"Last: {numbers[-1]}")

# %%
# Solution 3
person = ("Alice", 25, "Engineer")
name, age, job = person
print(f"Name: {name}, Age: {age}, Job: {job}")

# %%
# Solution 4
numbers = (1, 2, 5, 3, 5, 4, 5)
count = numbers.count(5)
print(f"Count of 5: {count}")

# %%
# Solution 5
fruits = ("apple", "banana", "cherry")
index = fruits.index("banana")
print(f"Index: {index}")

# %%
# Solution 6
numbers = {1, 2, 3, 4, 5}
print(numbers)

# %%
# Solution 7
my_list = [1, 2, 2, 3, 4, 4, 5]
unique = set(my_list)
print(unique)

# %%
# Solution 8
fruits = {"apple", "banana", "cherry"}
fruits.add("mango")
print(fruits)

# %%
# Solution 9
fruits = {"apple", "banana", "cherry"}
fruits.remove("banana")
print(fruits)

# %%
# Solution 10
fruits = {"apple", "banana", "cherry"}
result = "apple" in fruits
print(result)

# %%
# Solution 11
set1 = {1, 2, 3}
set2 = {3, 4, 5}
union = set1 | set2
print(union)

# %%
# Solution 12
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
intersection = set1 & set2
print(intersection)

# %%
# Solution 13
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5}
difference = set1 - set2
print(difference)

# %%
# Solution 14
numbers = {10, 20, 30, 40, 50}
length = len(numbers)
print(f"Length: {length}")

# %%
# Solution 15
coordinates = (10, 20)
x, y = coordinates
print(f"x = {x}, y = {y}")

# %% [markdown]
# ### Challenge Problem Solutions

# %%
# Challenge 1 Solution
set_a = {1, 2, 3, 4}
set_b = {3, 4, 5, 6}
symmetric_diff = set_a ^ set_b
print(f"Symmetric difference: {symmetric_diff}")

# %%
# Challenge 2 Solution
set_a = {1, 2}
set_b = {1, 2, 3, 4}
is_subset = set_a.issubset(set_b)
print(f"Is A subset of B? {is_subset}")

# %%
# Challenge 3 Solution
students = [("Alice", 85), ("Bob", 92), ("Charlie", 78)]
highest = students[0]
for student in students:
    if student[1] > highest[1]:
        highest = student
print(f"Highest scorer: {highest[0]} with {highest[1]} points")

# %%
# Challenge 4 Solution
set1 = {1, 2, 3, 4, 5}
set2 = {3, 4, 5, 6, 7}
set3 = {5, 6, 7, 8, 9}
common = set1 & set2 & set3
print(f"Common elements: {common}")

# %%
# Challenge 5 Solution
text = "programming"
unique_chars = set(text)
print(f"Unique characters: {unique_chars}")
print(f"Count: {len(unique_chars)}")

# %% [markdown]
# ---
#
# ## 🎉 Congratulations!
#
# You've completed Day 4! You now understand:
# - Tuples and their immutability
# - Tuple unpacking and practical uses
# - Sets and unique elements
# - Set operations (union, intersection, difference)
#
# ### Next Steps:
# - Practice using tuples for immutable data
# - Experiment with set operations
# - Ready for Day 5: Dictionaries!
#
# Keep building that foundation! 🚀

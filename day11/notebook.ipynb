# %% [markdown]
# # Day 11: Functions Basics\n\nWelcome to Day 11!\n\n---\n\n## 📚 Topic Introduction\n\nToday we'll learn about functions basics.\n\nKey concepts:\n- def keyword\n- parameters\n- return values\n\n---\n

# %% [markdown]
# ## 🔍 Syntax & Rules\n\nBasic syntax and important rules will be covered in the examples below.\n\n---\n

# %% [markdown]
# ## 💡 Examples

# %%
# Example 1: Functions Basics example\n\n# Your example code here\npass

# %%
# Example 2: Functions Basics example\n\n# Your example code here\npass

# %%
# Example 3: Functions Basics example\n\n# Your example code here\npass

# %%
# Example 4: Functions Basics example\n\n# Your example code here\npass

# %%
# Example 5: Functions Basics example\n\n# Your example code here\npass

# %%
# Example 6: Functions Basics example\n\n# Your example code here\npass

# %% [markdown]
# ---\n\n## ✏️ Practice Exercises

# %%
# Exercise 1: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 2: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 3: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 4: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 5: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 6: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 7: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 8: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 9: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 10: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 11: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 12: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 13: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 14: Practice exercise for Functions Basics\n\n# Your code here\n

# %%
# Exercise 15: Practice exercise for Functions Basics\n\n# Your code here\n

# %% [markdown]
# ---\n\n## 🎯 Challenge Problems

# %%
# Challenge 1: Advanced challenge for Functions Basics\n\n# Your code here\n

# %%
# Challenge 2: Advanced challenge for Functions Basics\n\n# Your code here\n

# %%
# Challenge 3: Advanced challenge for Functions Basics\n\n# Your code here\n

# %%
# Challenge 4: Advanced challenge for Functions Basics\n\n# Your code here\n

# %%
# Challenge 5: Advanced challenge for Functions Basics\n\n# Your code here\n

# %% [markdown]
# ---\n\n## ✅ Solutions\n\nPractice completing the exercises above, then implement your solutions!\nComplete solutions and additional examples can be found in the full course materials.

# %% [markdown]
# ---\n\n## 🎉 Congratulations!\n\nYou've completed Day 11!\n\nKeep practicing and move on to the next day when you're ready! 🚀
